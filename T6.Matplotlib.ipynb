# %% [markdown]
# # # Matplotlib
# # #Matplotlib is a low level graph plotting library in python that serves as a visualization utility.

# %% [markdown]
# ## Ploting Line Digram

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6,55])
ypoints=np.array([0,3,10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8,23])
ypoints = np.array([3,5,44])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,5,10])
ypoints = np.array([1,10,20])

plt.plot(xpoints, ypoints ,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2,5,18,19])
ypoints = np.array([3,1,2,10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=([1,4,17,10])

plt.title("Points with markers")
plt.plot(ypoints, marker='o')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(ypoints, marker='h')

# %% [markdown]
# Marker 	        Description
# 'o' 	         circle
# '*' 	         Star
# '.' 	         Point
# ',' 	         Pixel
# 'x' 	         X
# 'X' 	        X (filled)
# '+' 	        Plus
# 'P' 	        Plus (filled)
# 's' 	        Square
# 'D' 	        Diamond
# 'd' 	        Diamond (thin)
# 'p' 	        Pentagon
# 'H' 	        Hexagon
# 'h' 	        Hexagon
# 'v' 	        Triangle Down
# '^' 	        Triangle Up
# '<' 	        Triangle Left
# '>' 	        Triangle Right
# '1' 	        Tri Down
# '2' 	        Tri Up
# '3' 	        Tri Left
# '4' 	        Tri Right
# '|' 	        Vline
# '_' 	         Hline

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=([1,4,17,10])

plt.plot(ypoints, marker='*')# Star
plt.show()

plt.plot(ypoints, marker='.')#Point
plt.show()

plt.plot(ypoints, marker=',')# Pixel
plt.show()


plt.plot(ypoints, marker='x')# X
plt.show()

plt.plot(ypoints, marker='X')# X (filled)
plt.show()

plt.plot(ypoints, marker='+')# Plus
plt.show()

plt.plot(ypoints, marker='P')# 'P' Plus (filled
plt.show()

plt.plot(ypoints, marker='s')#  Square
plt.show()

plt.plot(ypoints, marker='D')# Diamond
plt.show()

plt.plot(ypoints, marker='d')#  Diamond (thin)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=([1,4,17,10])
ypoints2=([1,4,17,10])

plt.plot(ypoints, 'X--r')
plt.show()

plt.plot(ypoints2, 'X:g')
plt.show()

# %% [markdown]
# Line Syntax 	Description
# '-' 	Solid line
# ':' 	Dotted line
# '--' 	Dashed line
# '-.' 	Dashed/dotted line

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec='r', mfc='g')
plt.show()

# %% [markdown]
# ## Line operation

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, c='hotpink' ,linewidth = '20.5')
plt.show()

# %% [markdown]
# ## plotting multiple lines

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1, c='r')
plt.plot(y2)

plt.show()

# %% [markdown]
# ##  Set Font Properties for Title and Labels

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Position the Title

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Set Line Properties for the Grid

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = ':', linewidth = 1.0)

plt.show()

# %% [markdown]
# ## Subplot

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")
plt.xlabel("price")
plt.ylabel("avg")


#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.ylabel("avg")
plt.xlabel("Price")


plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([2,4,6,8])
y=np.array([3,5,8,12])

plt.scatter(x,y ,color='green')
plt.title("scatter plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")


plt.colorbar()
plt.show()

# %% [markdown]
# ## Bar plot

# %%
import matplotlib.pyplot as  plt
import numpy as np

x=np.array(['A','B','C','D'])
y=np.array([4,8,12,16])

plt.bar(x,y)
plt.show()

#we can change colour= and width= of bars

# %% [markdown]
# ##  Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ## Pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
